# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
sns.get_dataset_names()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("tips")
df
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
insight=df.describe(include='category')
insight
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
#Insight:
#This summary shows basic details of numeric data like count, average, minimum and maximum values, which helps to understand how the data is spread.
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
The dataset contains 244 records.
The average total bill is around 19.78 and the average tip is about 3.
Most group sizes are around 2 to 3 people.
The minimum total bill is 3.07 and the maximum is 50.81, showing a wide range of bills.

# %%
Insight:
There are 244 values in total for total_bill, tip, and size, and no data is missing.
The average total bill is around 19.8.
The average tip is close to 3.
The average group size is about 2 to 3 people.
The smallest bill is 3.07, and the largest bill is 50.81.
Tips range from 1 to 10.
Half of the customers spend less than 17.79 on the bill.
Most tables have 2 people, because the middle value (median) is 2.|

# %%
# null value treatment and imputation
A.fill the missing records:
     1.mean , median , mode
      2.

# %%
df.isna
# Out:
# <bound method DataFrame.isna of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
df.shape[0]
# Out:
# 244

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
(df. dropna ().shape [0]/df.shape [0])*100
# Out:
# 20.42648709315376

# %%
df. shape [0]
# Out:
# 891

# %%
( (891-182) /891)*100
# Out:
# 79.57351290684625

# %%
( (df. shape[0]-df.dropna () .shape[0])/df.shape[0])*100
# Out:
# 79.57351290684625

# %%
(df. isna().sum() /df.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['survived'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['age'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['pclass'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sibsp'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['parch'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['fare'],hue=df['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['who'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['embarked'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['class'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['alone'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['who'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['class'],hue=df['alive'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['sex'],hue=df['alive'],kde=True)
plt. show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df['alone'],hue=df['alive'],kde=True)
plt. show()
